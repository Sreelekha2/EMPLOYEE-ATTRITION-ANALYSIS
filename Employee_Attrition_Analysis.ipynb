# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
path="/content/drive/MyDrive/PROJECT/test.csv"

# %%
import pandas as pd

# %%
df=pd.read_csv(path)

# %%
df
# Out:
#        Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0            52685   36    Male                13  Healthcare            8029
# 1            30585   35    Male                 7   Education            4563
# 2            54656   50    Male                 7   Education            5583
# 3            33442   58    Male                44       Media            5525
# 4            15667   39    Male                24   Education            4604
# ...            ...  ...     ...               ...         ...             ...
# 14895        16243   56  Female                42  Healthcare            7830
# 14896        47175   30  Female                15   Education            3856
# 14897        12409   52    Male                 5   Education            5654
# 14898         9554   18    Male                 4   Education            5276
# 14899        73042   59  Female                48   Education            3774
#
# ...

# %%
df.isnull().sum()
# Out:
# Employee ID                 0
# Age                         0
# Gender                      0
# Years at Company            0
# Job Role                    0
# Monthly Income              0
# Work-Life Balance           0
# Job Satisfaction            0
# Performance Rating          0
# Number of Promotions        0
# Overtime                    0
# Distance from Home          0
# Education Level             0
# Marital Status              0
# Number of Dependents        0
# Job Level                   0
# Company Size                0
# Company Tenure              0
# Remote Work                 0
# Leadership Opportunities    0
# Innovation Opportunities    0
# Company Reputation          0
# Employee Recognition        0
# Attrition                   0
# dtype: int64

# %%
import numpy as np

# %%
df.replace("?",np.nan,inplace=True)

# %%
df.isnull().sum()
# Out:
# Employee ID                 0
# Age                         0
# Gender                      0
# Years at Company            0
# Job Role                    0
# Monthly Income              0
# Work-Life Balance           0
# Job Satisfaction            0
# Performance Rating          0
# Number of Promotions        0
# Overtime                    0
# Distance from Home          0
# Education Level             0
# Marital Status              0
# Number of Dependents        0
# Job Level                   0
# Company Size                0
# Company Tenure              0
# Remote Work                 0
# Leadership Opportunities    0
# Innovation Opportunities    0
# Company Reputation          0
# Employee Recognition        0
# Attrition                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14900 entries, 0 to 14899
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               14900 non-null  int64
#  1   Age                       14900 non-null  int64
#  2   Gender                    14900 non-null  object
#  3   Years at Company          14900 non-null  int64
#  4   Job Role                  14900 non-null  object
#  5   Monthly Income            14900 non-null  int64
#  6   Work-Life Balance         14900 non-null  object
#  7   Job Satisfaction          14900 non-null  object
#  8   Performance Rating        14900 non-null  object
#  9   Number of Promotions      14900 non-null  int64
#  10  Overtime                  14900 non-null  object
#  11  Distance from Home        14900 non-null  int64
#  12  Education Level           14900 non-null  object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14900 entries, 0 to 14899
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               14900 non-null  int64
#  1   Age                       14900 non-null  int64
#  2   Gender                    14900 non-null  object
#  3   Years at Company          14900 non-null  int64
#  4   Job Role                  14900 non-null  object
#  5   Monthly Income            14900 non-null  int64
#  6   Work-Life Balance         14900 non-null  object
#  7   Job Satisfaction          14900 non-null  object
#  8   Performance Rating        14900 non-null  object
#  9   Number of Promotions      14900 non-null  int64
#  10  Overtime                  14900 non-null  object
#  11  Distance from Home        14900 non-null  int64
#  12  Education Level           14900 non-null  object
# ...

# %%
df.describe()
# Out:
#         Employee ID           Age  Years at Company  Monthly Income  \
# count  14900.000000  14900.000000      14900.000000    14900.000000
# mean   37339.022081     38.385235         15.592416     7287.306040
# std    21453.129293     12.097904         11.133792     2156.737934
# min        5.000000     18.000000          1.000000     1226.000000
# 25%    18825.500000     28.000000          7.000000     5633.750000
# 50%    37433.000000     38.000000         13.000000     7332.000000
# 75%    55857.500000     49.000000         23.000000     8852.000000
# max    74471.000000     59.000000         51.000000    15063.000000
#
#        Number of Promotions  Distance from Home  Number of Dependents  \
# count          14900.000000        14900.000000          14900.000000
# mean               0.834362           49.927315              1.659329
# std                0.996511           28.702307              1.545401
# min                0.000000            1.000000              0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14900 entries, 0 to 14899
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               14900 non-null  int64
#  1   Age                       14900 non-null  int64
#  2   Gender                    14900 non-null  object
#  3   Years at Company          14900 non-null  int64
#  4   Job Role                  14900 non-null  object
#  5   Monthly Income            14900 non-null  int64
#  6   Work-Life Balance         14900 non-null  object
#  7   Job Satisfaction          14900 non-null  object
#  8   Performance Rating        14900 non-null  object
#  9   Number of Promotions      14900 non-null  int64
#  10  Overtime                  14900 non-null  object
#  11  Distance from Home        14900 non-null  int64
#  12  Education Level           14900 non-null  object
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
crosstab=pd.crosstab(df['Gender'],df['Attrition'])
crosstab.plot(kind='bar',stacked=True,figsize=(10,6),color=['#ff9999','#66b3ff'])
plt.title('Gender vs Attrition(Stacked)')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14900 entries, 0 to 14899
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               14900 non-null  int64
#  1   Age                       14900 non-null  int64
#  2   Gender                    14900 non-null  object
#  3   Years at Company          14900 non-null  int64
#  4   Job Role                  14900 non-null  object
#  5   Monthly Income            14900 non-null  int64
#  6   Work-Life Balance         14900 non-null  object
#  7   Job Satisfaction          14900 non-null  object
#  8   Performance Rating        14900 non-null  object
#  9   Number of Promotions      14900 non-null  int64
#  10  Overtime                  14900 non-null  object
#  11  Distance from Home        14900 non-null  int64
#  12  Education Level           14900 non-null  object
# ...

# %%
bins = [0, 3, 6, 9, df['Years at Company'].max()]
labels = ['0-3 years', '4-6 years', '7-9 years', '10+ years']
df['Years Category'] = pd.cut(df['Years at Company'], bins=bins, labels=labels, right=False)

grouped_df = df.groupby('Years Category')['Monthly Income'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='Years Category', y='Monthly Income', data=grouped_df, palette='viridis')

plt.xlabel('Years at Company Category')
plt.ylabel('Average Monthly Income')
plt.title('Average Monthly Income by Years at Company Category')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-18-528a9939ff83>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Years Category', y='Monthly Income', data=grouped_df, palette='viridis')

# %%
crosstab=pd.crosstab(df['Marital Status'],df['Attrition'])
crosstab.plot(kind='bar',stacked=True,figsize=(10,6),color=['#ff9999','#66b3ff'])
plt.title('Marital Status vs Attrition(Stacked)')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Job Satisfaction",hue="Attrition",color='pink',data=df,palette='Set2')
plt.title('Job Satisfaction Vs Attrition')
# Out:
# Text(0.5, 1.0, 'Job Satisfaction Vs Attrition')

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Gender",hue="Attrition",data=df,palette='Set2')
plt.title('Gender Vs Attrition')
# Out:
# Text(0.5, 1.0, 'Gender Vs Attrition')

# %%
sns.histplot(df['Age'],bins=10,edgecolor='black')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
crosstab=pd.crosstab(df['Age'],df['Attrition'])
crosstab.plot(kind='bar',stacked=True,figsize=(10,6),color=['#ff9999','#66b3ff'])
plt.title('Age vs Attrition(Stacked)')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Age",hue="Attrition",data=df,palette='Set2')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
df['Job Level'].value_counts()
# Out:
# Job Level
# Mid       5925
# Entry     5913
# Senior    3062
# Name: count, dtype: int64

# %%
df["Job Role"].value_counts()
# Out:
# Job Role
# Technology    3815
# Healthcare    3432
# Education     3168
# Media         2422
# Finance       2063
# Name: count, dtype: int64

# %%
df["Attrition"]
# Out:
# 0        Stayed
# 1          Left
# 2        Stayed
# 3          Left
# 4        Stayed
#           ...
# 14895    Stayed
# 14896      Left
# 14897      Left
# 14898    Stayed
# 14899      Left
# Name: Attrition, Length: 14900, dtype: object

# %%
left_df=df[df['Attrition']=='Left']

# %%
stay_df=df[df['Attrition']=='Stayed']

# %%
plt.figure(figsize=(14,6))

plt.subplot(1,2,1)
left_df["Job Role"].value_counts().plot.pie(autopct='%1.1f%%',colors=['#ff9999','#66b3ff','#99ff99'])
plt.title('Job Role Distribution of left')

plt.subplot(1,2,2)
stay_df["Job Role"].value_counts().plot.pie(autopct='%1.1f%%',colors=['#ff9999','#66b3ff','#99ff99'])
plt.title('Job Role Distribution of Stayed')

plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(14,6))

plt.subplot(1,2,1)
left_df["Job Level"].value_counts().plot.pie(autopct='%1.1f%%',colors=['#ff9999','#66b3ff','#99ff99'])
plt.title('Job Level  Distribution of left')

plt.subplot(1,2,2)
stay_df["Job Level"].value_counts().plot.pie(autopct='%1.1f%%',colors=['#ff9999','#66b3ff','#99ff99'])
plt.title('Job Level Distribution of Stayed')

plt.tight_layout()

plt.show()

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      8087
# Female    6813
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14,6))

plt.subplot(1,2,1)
left_df["Gender"].value_counts().plot.pie(autopct='%1.1f%%',colors=['#ff9999','#66b3ff','#99ff99'])
plt.title('Gender   Distribution -left the Company')

plt.subplot(1,2,2)
stay_df["Gender"].value_counts().plot.pie(autopct='%1.1f%%',colors=['#ff9999','#66b3ff','#99ff99'])
plt.title('Gender Distribution - Stayed in the Company')

plt.tight_layout()

plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14900 entries, 0 to 14899
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               14900 non-null  int64
#  1   Age                       14900 non-null  int64
#  2   Gender                    14900 non-null  object
#  3   Years at Company          14900 non-null  int64
#  4   Job Role                  14900 non-null  object
#  5   Monthly Income            14900 non-null  int64
#  6   Work-Life Balance         14900 non-null  object
#  7   Job Satisfaction          14900 non-null  object
#  8   Performance Rating        14900 non-null  object
#  9   Number of Promotions      14900 non-null  int64
#  10  Overtime                  14900 non-null  object
#  11  Distance from Home        14900 non-null  int64
#  12  Education Level           14900 non-null  object
# ...

# %% [markdown]
# FEATURE ENGINEERING

# %%
df["Gender"].replace("Male",0,inplace=True)

# %%
df["Gender"].replace("Female",1,inplace=True)

# %%
df["Job Role"].value_counts()
# Out:
# Job Role
# Technology    3815
# Healthcare    3432
# Education     3168
# Media         2422
# Finance       2063
# Name: count, dtype: int64

# %%
df["Job Role"].replace("Media",0,inplace=True)

# %%
df["Job Role"].replace("Education",1,inplace=True)

# %%
df["Job Role"].replace("Healthcare",2,inplace=True)

# %%
df["Job Role"].replace("Finance",3,inplace=True)

# %%
df["Job Role"].replace("Technology",4,inplace=True)

# %%
df["Work-Life Balance"].value_counts()
# Out:
# Work-Life Balance
# Good         5630
# Fair         4483
# Excellent    2713
# Poor         2074
# Name: count, dtype: int64

# %%
df["Work-Life Balance"].replace("Poor",0,inplace=True)

# %%
df["Work-Life Balance"].replace("Fair",1,inplace=True)

# %%
df["Work-Life Balance"].replace("Good",2,inplace=True)

# %%
df["Work-Life Balance"].replace("Excellent",3,inplace=True)

# %%
df["Job Satisfaction"].value_counts()
# Out:
# Job Satisfaction
# High         7466
# Very High    2968
# Medium       2900
# Low          1566
# Name: count, dtype: int64

# %%
df["Job Satisfaction"].replace("Low",0,inplace=True)

# %%
df["Job Satisfaction"].replace("Medium",1,inplace=True)

# %%
df["Job Satisfaction"].replace("High",2,inplace=True)

# %%
df["Job Satisfaction"].replace("Very High",3,inplace=True)

# %%
df["Performance Rating"].value_counts()
# Out:
# Performance Rating
# Average          8909
# High             3022
# Below Average    2189
# Low               780
# Name: count, dtype: int64

# %%
df["Performance Rating"].replace("Low",0,inplace=True)

# %%
df["Performance Rating"].replace("Below Average",1,inplace=True)

# %%
df["Performance Rating"].replace("Average",2,inplace=True)

# %%
df["Performance Rating"].replace("High",3,inplace=True)

# %%
df["Job Level"].value_counts()
# Out:
# Job Level
# Mid       5925
# Entry     5913
# Senior    3062
# Name: count, dtype: int64

# %%
df["Job Level"].replace("Entry",0,inplace=True)

# %%
df["Job Level"].replace("Mid",1,inplace=True)

# %%
df["Job Level"].replace("Senior",2,inplace=True)

# %%
df["Company Size"].value_counts()
# Out:
# Company Size
# Medium    7486
# Small     4420
# Large     2994
# Name: count, dtype: int64

# %%
df["Company Size"].replace("Small",0,inplace=True)

# %%
df["Company Size"].replace("Medium",1,inplace=True)

# %%
df["Company Size"].replace("Large",2,inplace=True)

# %%
df["Remote Work"].value_counts()
# Out:
# Remote Work
# No     12061
# Yes     2839
# Name: count, dtype: int64

# %%
df["Remote Work"].replace("Yes",1,inplace=True)

# %%
df["Remote Work"].replace("No",0,inplace=True)

# %%
df["Leadership Opportunities"].value_counts()
# Out:
# Leadership Opportunities
# No     14165
# Yes      735
# Name: count, dtype: int64

# %%
df["Leadership Opportunities"].replace("No",0,inplace=True)

# %%
df["Leadership Opportunities"].replace("Yes",1,inplace=True)

# %%
df["Innovation Opportunities"].value_counts()
# Out:
# Innovation Opportunities
# No     12499
# Yes     2401
# Name: count, dtype: int64

# %%
df["Innovation Opportunities"].replace("No",0,inplace=True)

# %%
df["Innovation Opportunities"].replace("Yes",1,inplace=True)

# %%
df["Company Reputation"].value_counts()
# Out:
# Company Reputation
# Good         7416
# Poor         3082
# Fair         2969
# Excellent    1433
# Name: count, dtype: int64

# %%
df["Company Reputation"].replace("Poor",0,inplace=True)

# %%
df["Company Reputation"].replace("Fair",1,inplace=True)

# %%
df["Company Reputation"].replace("Good",2,inplace=True)

# %%
df["Company Reputation"].replace("Excellent",3,inplace=True)

# %%
df["Employee Recognition"].value_counts()
# Out:
# Employee Recognition
# Low          5862
# Medium       4624
# High         3706
# Very High     708
# Name: count, dtype: int64

# %%
df["Employee Recognition"].replace("Low",0,inplace=True)

# %%
df["Employee Recognition"].replace("Medium",1,inplace=True)

# %%
df["Employee Recognition"].replace("High",2,inplace=True)

# %%
df["Employee Recognition"].replace("Very High",0,inplace=True)

# %%
df["Marital Status"].value_counts()
# Out:
# Marital Status
# Married     7511
# Single      5166
# Divorced    2223
# Name: count, dtype: int64

# %%
df["Marital Status"].value_counts()
# Out:
# Marital Status
# Married     7511
# Single      5166
# Divorced    2223
# Name: count, dtype: int64

# %%
df["Marital Status"].replace("Married",1,inplace=True)

# %%
df["Marital Status"].replace("Single",0,inplace=True)

# %%
df["Marital Status"].replace("Divorced",2,inplace=True)

# %%
df["Education Level"].value_counts()
# Out:
# Education Level
# Bachelor’s Degree    4505
# Associate Degree     3734
# Master’s Degree      3001
# High School          2932
# PhD                   728
# Name: count, dtype: int64

# %%
df["Education Level"].replace("High School",0,inplace=True)

# %%
df["Education Level"].replace("Bachelor’s Degree",1,inplace=True)

# %%
df["Education Level"].replace("Associate Degree",2,inplace=True)

# %%
df["Education Level"].replace("Master’s Degree",3,inplace=True)

# %%
df["Education Level"].replace("PhD",4,inplace=True)

# %%
df["Innovation Opportunities"].value_counts()
# Out:
# Innovation Opportunities
# 0    12499
# 1     2401
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14900 entries, 0 to 14899
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               14900 non-null  int64
#  1   Age                       14900 non-null  int64
#  2   Gender                    14900 non-null  int64
#  3   Years at Company          14900 non-null  int64
#  4   Job Role                  14900 non-null  int64
#  5   Monthly Income            14900 non-null  int64
#  6   Work-Life Balance         14900 non-null  int64
#  7   Job Satisfaction          14900 non-null  int64
#  8   Performance Rating        14900 non-null  int64
#  9   Number of Promotions      14900 non-null  int64
#  10  Overtime                  14900 non-null  object
#  11  Distance from Home        14900 non-null  int64
#  12  Education Level           14900 non-null  int64
#  13  Marital Status            14900 non-null  int64
# ...

# %%
df["Overtime"].value_counts()
# Out:
# Overtime
# No     10009
# Yes     4891
# Name: count, dtype: int64

# %%
df["Overtime"].replace("Yes",1,inplace=True)

# %%
df["Overtime"].replace("No",0,inplace=True)

# %%
df["Years Category"]
# Out:
# 0        10+ years
# 1        7-9 years
# 2        7-9 years
# 3        10+ years
# 4        10+ years
#            ...
# 14895    10+ years
# 14896    10+ years
# 14897    4-6 years
# 14898    4-6 years
# 14899    10+ years
# Name: Years Category, Length: 14900, dtype: category
# Categories (4, object): ['0-3 years' < '4-6 years' < '7-9 years' < '10+ years']

# %%
df["Years Category"].value_counts()
# Out:
# Years Category
# 10+ years    10031
# 4-6 years     1824
# 7-9 years     1817
# 0-3 years     1221
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14900 entries, 0 to 14899
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               14900 non-null  int64
#  1   Age                       14900 non-null  int64
#  2   Gender                    14900 non-null  int64
#  3   Years at Company          14900 non-null  int64
#  4   Job Role                  14900 non-null  int64
#  5   Monthly Income            14900 non-null  int64
#  6   Work-Life Balance         14900 non-null  int64
#  7   Job Satisfaction          14900 non-null  int64
#  8   Performance Rating        14900 non-null  int64
#  9   Number of Promotions      14900 non-null  int64
#  10  Overtime                  14900 non-null  int64
#  11  Distance from Home        14900 non-null  int64
#  12  Education Level           14900 non-null  int64
#  13  Marital Status            14900 non-null  int64
# ...

# %%
X=df[["Employee ID","Age","Gender","Years at Company","Job Role","Monthly Income","Work-Life Balance","Job Satisfaction","Performance Rating","Number of Promotions","Overtime","Distance from Home","Employee Recognition","Company Reputation","Innovation Opportunities","Leadership Opportunities","Remote Work","Company Tenure","Company Size","Job Level","Number of Dependents","Marital Status","Education Level",]]

# %%
Y=df["Attrition"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
X_train
# Out:
#        Employee ID  Age  Gender  Years at Company  Job Role  Monthly Income  \
# 13553         2073   28       1                 7         3           11324
# 3923         71047   42       1                33         0            6728
# 10055        44286   38       0                27         4            9701
# 13197        24951   59       1                39         4            9127
# 8659         74164   47       1                 3         0            6230
# ...            ...  ...     ...               ...       ...             ...
# 6889          7912   37       0                 5         1            3970
# 9127         39859   52       0                10         2            8485
# 11635        46683   31       0                22         1            3921
# 2573         57753   52       1                 9         3            8184
# 2794         33266   29       1                11         4            9268
#
# ...

# %%
Y_train
# Out:
# 13553    Stayed
# 3923     Stayed
# 10055      Left
# 13197    Stayed
# 8659       Left
#           ...
# 6889       Left
# 9127     Stayed
# 11635    Stayed
# 2573       Left
# 2794     Stayed
# Name: Attrition, Length: 11920, dtype: object

# %%
X_train.shape
# Out:
# (11920, 23)

# %%
Y_train.shape
# Out:
# (11920,)

# %%
X_test.shape
# Out:
# (2980, 23)

# %%
Y_test.shape
# Out:
# (2980,)

# %% [markdown]
# # DECISION TREE

# %%
from sklearn import tree
clf=tree.DecisionTreeClassifier(criterion='gini',splitter='random')

# %%
model=clf.fit(X_train, Y_train)

# %%
tree.plot_tree(clf)
plt.show()

# %%
Y_train_pred=model.predict(X_train)

# %%
Y_train_pred[0:5]
# Out:
# array(['Stayed', 'Stayed', 'Left', 'Stayed', 'Left'], dtype=object)

# %%
Y_test[0:5]
# Out:
# 2402     Stayed
# 7507       Left
# 6590       Left
# 7569     Stayed
# 14650    Stayed
# Name: Attrition, dtype: object

# %% [markdown]
# ACCURACY FOR TRAIN

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score, roc_curve, precision_recall_curve

# %%
from sklearn.preprocessing import StandardScaler

# %%
train_accuracy=accuracy_score(Y_train,Y_train_pred)

# %%
print("Training Accuracy:",train_accuracy)
# Out:
# Training Accuracy: 1.0

# %% [markdown]
# ACCURACY FOR TEST

# %%
Y_test_pred=model.predict(X_test)

# %%
test_accuracy=accuracy_score(Y_test,Y_test_pred)

# %%
print("Accuracy_test",test_accuracy)
# Out:
# Accuracy_test 0.6546979865771813

# %% [markdown]
# CLASSIFICATION REPORT ON TRAIN

# %%
print(classification_report(Y_train,Y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#         Left       1.00      1.00      1.00      5594
#       Stayed       1.00      1.00      1.00      6326
#
#     accuracy                           1.00     11920
#    macro avg       1.00      1.00      1.00     11920
# weighted avg       1.00      1.00      1.00     11920

# %% [markdown]
# CONFUSION MATRIX FOR TRAINING

# %%
print(confusion_matrix(Y_train,Y_train_pred))
# Out:
# [[5594    0]
#  [   0 6326]]

# %% [markdown]
# CLASSIFICATION REPORT ON TEST

# %%
print(classification_report(Y_test,Y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#         Left       0.65      0.63      0.64      1438
#       Stayed       0.66      0.68      0.67      1542
#
#     accuracy                           0.65      2980
#    macro avg       0.65      0.65      0.65      2980
# weighted avg       0.65      0.65      0.65      2980

# %% [markdown]
# CONFUSION MATRIX FOR TRAINING

# %%
print(confusion_matrix(Y_test,Y_test_pred))
# Out:
# [[ 902  536]
#  [ 493 1049]]

# %% [markdown]
# **SVC**

# %%
from sklearn.svm import SVC

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
clf=SVC(kernel='rbf')
clf.fit(X_train,Y_train)
# Out:
# SVC()

# %%
X_train_scaled=scaler.fit_transform(X_train)

# %%
X_test_scaled=scaler.fit_transform(X_test)

# %% [markdown]
# Accuracy of train

# %%
train_accuracy=accuracy_score(Y_train,Y_train_pred)

# %%
print("Training Accuracy:",train_accuracy)
# Out:
# Training Accuracy: 0.5307046979865772

# %%
Y_test_pred=clf.predict(X_test)

# %% [markdown]
# Accuracy of test

# %%
test_accuracy=accuracy_score(Y_test,Y_test_pred)

# %%
print("Testing Accuracy:",test_accuracy)
# Out:
# Testing Accuracy: 0.5174496644295302

# %% [markdown]
# Confusion matrix on train

# %%
print(confusion_matrix(Y_train,Y_train_pred))
# Out:
# [[   0 5594]
#  [   0 6326]]

# %% [markdown]
# Confusion ON TESTING

# %%
print(confusion_matrix(Y_test,Y_test_pred))
# Out:
# [[   0 1438]
#  [   0 1542]]

# %% [markdown]
# ## LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train_scaled=scaler.fit_transform(X_train)

# %%
x_test_scaled=scaler.fit_transform(X_test)

# %%
logreg=LogisticRegression(random_state=42)

# %%
logreg.fit(X_train_scaled,Y_train)
# Out:
# LogisticRegression(random_state=42)

# %% [markdown]
# ACCURACY OF LOGISTIC REGRESSION ON TRAIN

# %%
Y_train_pred=logreg.predict(X_train_scaled)

# %%
accuracy=accuracy_score(Y_train,Y_train_pred)

# %%
print("Training Accuracy:",accuracy)
# Out:
# Training Accuracy: 0.7328859060402685

# %% [markdown]
# ACCURACY OF LOGISTIC REGRESSION ON TEST

# %%
Y_test_pred=logreg.predict(x_test_scaled)

# %%
accuracy=accuracy_score(Y_test,Y_test_pred)

# %%
print("Testing Accuracy:",accuracy)
# Out:
# Testing Accuracy: 0.7194630872483222

# %% [markdown]
# CLASSIFICATION REPORT AND CONFUSION MATRIX ON TRAINING

# %%
print(classification_report(Y_train,Y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#         Left       0.72      0.70      0.71      5594
#       Stayed       0.74      0.76      0.75      6326
#
#     accuracy                           0.73     11920
#    macro avg       0.73      0.73      0.73     11920
# weighted avg       0.73      0.73      0.73     11920

# %%
print(confusion_matrix(Y_train,Y_train_pred))
# Out:
# [[3933 1661]
#  [1523 4803]]

# %% [markdown]
# CLASSIFICATION REPORT AND CONFUSION MATRIX ON TRAINING

# %%
print(classification_report(Y_test,Y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#         Left       0.72      0.69      0.70      1438
#       Stayed       0.72      0.75      0.73      1542
#
#     accuracy                           0.72      2980
#    macro avg       0.72      0.72      0.72      2980
# weighted avg       0.72      0.72      0.72      2980

# %%
print(confusion_matrix(Y_test,Y_test_pred))
# Out:
# [[ 993  445]
#  [ 391 1151]]

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_classifier=RandomForestClassifier(random_state=42)

# %%
rf_classifier.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# ACCURACY,CLASSIFICATION REPORT,CONFUSION MATRIX ON TRAINING
#  (RandomForestClassifier)

# %%
Y_train_pred=rf_classifier.predict(X_train)

# %%
accuracy=accuracy_score(Y_train,Y_train_pred)

# %%
print("Training Accuracy",accuracy)
# Out:
# Training Accuracy 1.0

# %% [markdown]
# ACCURACY, CLASSIFICATION REPORT,CONFUSION MATRIX ON TESTING(RandomForestClassifier)

# %%
Y_test_pred=rf_classifier.predict(X_test)

# %%
accuracy=accuracy_score(Y_test,Y_test_pred)

# %%
print("Testing Accuracy :",accuracy)
# Out:
# Testing Accuracy : 0.7345637583892617

# %%
print(classification_report(Y_test,Y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#         Left       0.74      0.69      0.71      1438
#       Stayed       0.73      0.78      0.75      1542
#
#     accuracy                           0.73      2980
#    macro avg       0.74      0.73      0.73      2980
# weighted avg       0.74      0.73      0.73      2980

# %%
print(confusion_matrix(Y_test,Y_test_pred))
# Out:
# [[ 986  452]
#  [ 339 1203]]
